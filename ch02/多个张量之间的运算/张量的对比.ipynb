# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
#二维张量
t1=tf.constant(
    [
        [1,5,7],
        [2,3,8]
    ]
,tf.float32)

#二维张量
t2=tf.constant(
    [
        [2,5,6],
        [7,1,8]
    ]
,tf.float32)

# 两个张量的对比
r=tf.equal(t1,t2)

session=tf.Session()
print(session.run(r))
# Out:
# [[False  True False]
#  [False False  True]]
