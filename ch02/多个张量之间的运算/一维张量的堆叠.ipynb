# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
#长度为3的一维张量
t1=tf.constant([1,2,3],tf.float32)
#长度为3的一维张量
t2=tf.constant([7,8,9],tf.float32)

session=tf.Session()

#在0方向上堆叠
t=tf.stack([t1,t2],0)
#打印结果
print('在0方向上堆叠:',session.run(t))

#在1方向上堆叠
t=tf.stack([t1,t2],1)
#打印结果
print('在1方向上堆叠:',session.run(t))
# Out:
# 在0方向上堆叠: [[1. 2. 3.]
#  [7. 8. 9.]]
# 在1方向上堆叠: [[1. 7.]
#  [2. 8.]
#  [3. 9.]]
