# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
#二维张量
x=tf.constant([[1,2,3] ,[4,5,6]] ,tf.float32)
#常数边界扩充, 上侧补1行10, 下侧补2行10 , 右侧补 1列10
r=tf.pad(x,[[1,2],[0,1]] ,mode='CONSTANT',constant_values=10)
session=tf.Session()
print(session.run(r))
# Out:
# [[10. 10. 10. 10.]
#  [ 1.  2.  3. 10.]
#  [ 4.  5.  6. 10.]
#  [10. 10. 10. 10.]
#  [10. 10. 10. 10.]]
