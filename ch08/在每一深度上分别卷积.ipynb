# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
#1个3行2列2深度的张量
x=tf.constant(
    [
        [
            [[2,5],[3,3],[8,2]],
            [[6,1],[1,2],[5,4]],
            [[7,9],[2,3],[-1,3]]
        ]
    ]
,tf.float32)
#1个2行2列2深度的卷积核
k=tf.constant([
[[[3],[1]] ,[[-2],[2]]],
    [[[-1],[-3]] ,[[4],[5]]]
],tf.float32)

#每一深度分别计算卷积,然后求和
x_conv2d_k=tf.nn.depthwise_conv2d(x,k,[1,1,1,1],"VALID")
session=tf.Session()
print(session.run(x_conv2d_k))
# Out:
# [[[[ -2.  18.]
#    [ 12.  21.]]
#
#   [[ 17.  -7.]
#    [-13.  16.]]]]
