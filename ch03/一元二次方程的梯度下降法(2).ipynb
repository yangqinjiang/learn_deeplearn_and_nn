# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import math

#将变量初始化, 梯度下降的初始点
x=tf.Variable(15.0,dtype=tf.float32)
#函数
y=tf.pow(x-1, 2.0)

#梯度下降,学习率设置为0.05
opti = tf.train.GradientDescentOptimizer(0.05).minimize(y)
# 画曲线
value=np.arange(-15, 17, 0.01)
y_value=np.power(value-1 ,2.0)
plt.plot(value, y_value)

#创建会话
session=tf.Session()
session.run(tf.global_variables_initializer())

#100次迭代
for i in range(100):
    session.run(opti)
    if( i%10 == 0):
        v=session.run(x)
        plt.plot(v,math.pow(v-1, 2.0),'go')
        print('第%d次的x的迭代值: %f' % (i+1, v))
plt.show()


# 从输出结果可以看出, 随着迭代次数的增加, 找到的位置点越来越靠近最小值点x=1
# Out:
# 第1次的x的迭代值: 13.600000
# 第11次的x的迭代值: 5.393349
# 第21次的x的迭代值: 2.531866
# 第31次的x的迭代值: 1.534129
# 第41次的x的迭代值: 1.186239
# 第51次的x的迭代值: 1.064938
# 第61次的x的迭代值: 1.022642
# 第71次的x的迭代值: 1.007895
# 第81次的x的迭代值: 1.002753
# 第91次的x的迭代值: 1.000960
